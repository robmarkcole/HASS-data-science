# %% [markdown]
# Have started a MariaDB instance on Hassio and configured as a recorder
#
# https://mariadb.com/resources/blog/how-connect-python-programs-mariadb
#
# https://github.com/robmarkcole/HASS-Google-Cloud-SQL/blob/master/HA-cloud-SQL%20usage.ipynb
#
# ```
# {
#   "databases": [
#     "ha_db"
#   ],
#   "logins": [
#     {
#       "username": "hass",
#       "host": "%",
#       "password": "pass"
#     }
#   ],
#   "rights": [
#     {
#       "username": "hass",
#       "host": "%",
#       "database": "ha_db",
#       "grant": "ALL PRIVILEGES ON"
#     }
#   ]
# }
# ```

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
config_url = "mysql://hass:pass@core-mariadb/ha_db"

# %% [markdown]
# Replace core-mariadb with IP and port of Hassio = "192.168.0.28:3306"

# %%
settings = {
   'user': 'hass',
   'pass': 'pass',
   'IP': "192.168.0.XX",
   'port': "3306",
   'db': 'ha_db'
}

url = 'mysql+pymysql://{user}:{pass}@{IP}:{port}/{db}'.format(**settings)
print(url)
# Out:
# mysql+pymysql://hass:pass@192.168.0.XX:3306/ha_db

# %%
engine = create_engine(url)

# %%
# %%time
entity_id_list =  list(engine.execute("SELECT entity_id, COUNT(*) FROM states \
GROUP BY entity_id ORDER by 2 DESC"))
# Out:
# CPU times: user 11.6 ms, sys: 3.42 ms, total: 15.1 ms
# Wall time: 157 ms

# %%
sql = "SELECT entity_id, COUNT(*) FROM states \
GROUP BY entity_id ORDER by 2 DESC"
print('Performing query...')
df = pd.read_sql(sql, con=engine)
# Out:
# Performing query...

# %%
df
# Out:
#                                entity_id  COUNT(*)
# 0                                sun.sun        37
# 1       sensor.living_room_motion_sensor        28
# 2             sensor.exchange_rate_1_btc         7
# 3           sensor.bedroom_motion_sensor         6
# 4                automation.doorbell_off         2
# 5                 automation.doorbell_on         2
# 6              sensor.hall_motion_sensor         2
# 7                  group.all_automations         2
# 8                    sensor.trade_volume         2
# 9                       sensor.yr_symbol         2
# 10                 media_player.apple_tv         2
# 11                       remote.apple_tv         1
# 12                  script.1513348085745         1
# 13                binary_sensor.doorbell         1
# 14        configurator.plex_media_server         1
# 15                    sensor.hall_remote         1
# 16                        sensor.hue_tap         1
# ...
